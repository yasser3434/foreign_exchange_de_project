# %%
import os
import json
import requests
from dotenv import load_dotenv

# %%
load_dotenv()

api_key = os.getenv("api_key")

# %%
load_dotenv()

url = f'https://v6.exchangerate-api.com/v6/{api_key}/latest/EUR'

response = requests.get(url)
data = response.json()

# %%
print(data)
# Out:
# {'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1772398802, 'time_last_update_utc': 'Sun, 01 Mar 2026 21:00:02 +0000', 'time_next_update_unix': 1772402402, 'time_next_update_utc': 'Sun, 01 Mar 2026 22:00:02 +0000', 'base_code': 'EUR', 'conversion_rates': {'EUR': 1, 'AED': 4.3277788, 'AFN': 74.75860313, 'ALL': 96.25595346, 'AMD': 445.40306859, 'ANG': 2.10938708, 'AOA': 1093.52665027, 'ARS': 1711.37284083, 'AUD': 1.66549486, 'AWG': 2.10938708, 'AZN': 2.00784572, 'BAM': 1.95583, 'BBD': 2.35685707, 'BDT': 144.33829705, 'BGN': 1.95583, 'BHD': 0.44308913, 'BIF': 3505.98865914, 'BMD': 1.17842854, 'BND': 1.49391645, 'BOB': 8.17490373, 'BRL': 6.06918813, 'BSD': 1.17842854, 'BTN': 107.51924901, 'BWP': 15.98279336, 'BYN': 3.40068762, 'BZD': 2.35685707, 'CAD': 1.60910711, 'CDF': 2693.41791045, 'CHF': 0.9059116, 'CLF': 0.02598802, 'CLP': 1027.25338189, 'CNH': 8.09883275, 'CNY': 8.08125598, 'COP': 4398.05693413, 'CRC': 558.58544719, 'CUP': 28.28228485, 'CVE': 110.265, 'CZK': 24.24255538, 'DJF': 209.43149778, 'DKK': 7.46083908, 'DOP': 70.60149198, 'DZD': 153.48572587, 'EGP': 56.63589502, 'ERN': 17.67642803, 'ETB': 184.40450181, 'FJD': 2.57418133, 'FKP': 0.87614074, 'FOK': 7.46083905, 'GBP': 0.87626048, 'GEL': 3.1583682, 'GGP': 0.87614074, 'GHS': 12.62230484, 'GIP': 0.87614074, 'GMD': 87.60128188, 'GNF': 10316.87038433, 'GTQ': 9.05846576, 'GYD': 247.20410959, 'HKD': 9.21741846, 'HNL': 31.25883953, 'HRK': 7.5345, 'HTG': 154.9669386, 'HUF': 376.47929425, 'IDR': 19836.83896902, 'ILS': 3.69763499, 'IMP': 0.87614074, 'INR': 107.51934756, 'IQD': 1549.00429185, 'IRR': 1549079.88412009, 'ISK': 143.45858115, 'JEP': 0.87614074, 'JMD': 184.38938175, 'JOD': 0.83550583, 'JPY': 183.88112091, 'KES': 152.35576841, 'KGS': 103.30330763, 'KHR': 4748.92105263, 'KID': 1.6651015, 'KMF': 491.96775, 'KRW': 1702.28401933, 'KWD': 0.36104653, 'KYD': 0.98202339, 'KZT': 588.71379125, 'LAK': 25720.71500982, 'LBP': 105469.35393634, 'LKR': 364.37831482, 'LRD': 216.75274998, 'LSL': 18.88232198, 'LYD': 7.46129993, 'MAD': 10.80914099, 'MDL': 20.1260567, 'MGA': 4944.06807089, 'MKD': 61.6948, 'MMK': 2487.96429077, 'MNT': 4184.52465278, 'MOP': 9.49216753, 'MRU': 47.3148925, 'MUR': 54.68650178, 'MVR': 18.26158613, 'MWK': 2052.81852401, 'MXN': 20.38537078, 'MYR': 4.59517659, 'MZN': 75.55682259, 'NAD': 18.88232198, 'NGN': 1599.14562768, 'NIO': 43.45924211, 'NOK': 11.21742644, 'NPR': 172.03079842, 'NZD': 1.97341347, 'OMR': 0.45310224, 'PAB': 1.17842854, 'PEN': 3.9629113, 'PGK': 5.14540601, 'PHP': 68.1540011, 'PKR': 330.38630829, 'PLN': 4.22468543, 'PYG': 7667.64768056, 'QAR': 4.28947987, 'RON': 5.09490219, 'RSD': 117.45122636, 'RUB': 91.32515416, 'RWF': 1720.06705314, 'SAR': 4.41910701, 'SBD': 9.29847539, 'SCR': 16.55805215, 'SDG': 528.43045388, 'SEK': 10.66851598, 'SGD': 1.4939172, 'SHP': 0.87614074, 'SLE': 28.84812942, 'SLL': 28848.23854747, 'SOS': 674.61308411, 'SRD': 44.64044527, 'SSP': 5414.00038168, 'STN': 24.5, 'SYP': 135.87603033, 'SZL': 18.88232198, 'THB': 36.68469217, 'TJS': 11.08250613, 'TMT': 4.13312443, 'TND': 3.38044622, 'TOP': 2.74744398, 'TRY': 51.78950638, 'TTD': 8.60348582, 'TVD': 1.6651015, 'TWD': 37.06021319, 'TZS': 3016.86267936, 'UAH': 50.93754607, 'UGX': 4227.42149069, 'USD': 1.17858471, 'UYU': 45.40690638, 'UZS': 14414.69411932, 'VES': 495.60601336, 'VND': 30457.73749569, 'VUV': 138.59240474, 'WST': 3.13575042, 'XAF': 655.957, 'XCD': 3.18175705, 'XCG': 2.10938708, 'XDR': 0.85842039, 'XOF': 655.957, 'XPF': 119.332, 'YER': 281.49797662, 'ZAR': 18.88551489, 'ZMW': 22.22841983, 'ZWG': 30.44219996, 'ZWL': 30.4422}}

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "result": "success",
#   "documentation": "https://www.exchangerate-api.com/docs",
#   "terms_of_use": "https://www.exchangerate-api.com/terms",
#   "time_last_update_unix": 1772398802,
#   "time_last_update_utc": "Sun, 01 Mar 2026 21:00:02 +0000",
#   "time_next_update_unix": 1772402402,
#   "time_next_update_utc": "Sun, 01 Mar 2026 22:00:02 +0000",
#   "base_code": "EUR",
#   "conversion_rates": {
#     "EUR": 1,
#     "AED": 4.3277788,
#     "AFN": 74.75860313,
#     "ALL": 96.25595346,
#     "AMD": 445.40306859,
#     "ANG": 2.10938708,
#     "AOA": 1093.52665027,
#     "ARS": 1711.37284083,
#     "AUD": 1.66549486,
#     "AWG": 2.10938708,
#     "AZN": 2.00784572,
#     "BAM": 1.95583,
#     "BBD": 2.35685707,
#     "BDT": 144.33829705,
#     "BGN": 1.95583,
#     "BHD": 0.44308913,
#     "BIF": 3505.98865914,
#     "BMD": 1.17842854,
#     "BND": 1.49391645,
#     "BOB": 8.17490373,
#     "BRL": 6.06918813,
#     "BSD": 1.17842854,
#     "BTN": 107.51924901,
#     "BWP": 15.98279336,
#     "BYN": 3.40068762,
#     "BZD": 2.35685707,
#     "CAD": 1.60910711,
#     "CDF": 2693.41791045,
#     "CHF": 0.9059116,
#     "CLF": 0.02598802,
#     "CLP": 1027.25338189,
#     "CNH": 8.09883275,
#     "CNY": 8.08125598,
#     "COP": 4398.05693413,
#     "CRC": 558.58544719,
#     "CUP": 28.28228485,
#     "CVE": 110.265,
#     "CZK": 24.24255538,
#     "DJF": 209.43149778,
#     "DKK": 7.46083908,
#     "DOP": 70.60149198,
#     "DZD": 153.48572587,
#     "EGP": 56.63589502,
#     "ERN": 17.67642803,
#     "ETB": 184.40450181,
#     "FJD": 2.57418133,
#     "FKP": 0.87614074,
#     "FOK": 7.46083905,
#     "GBP": 0.87626048,
#     "GEL": 3.1583682,
#     "GGP": 0.87614074,
#     "GHS": 12.62230484,
#     "GIP": 0.87614074,
#     "GMD": 87.60128188,
#     "GNF": 10316.87038433,
#     "GTQ": 9.05846576,
#     "GYD": 247.20410959,
#     "HKD": 9.21741846,
#     "HNL": 31.25883953,
#     "HRK": 7.5345,
#     "HTG": 154.9669386,
#     "HUF": 376.47929425,
#     "IDR": 19836.83896902,
#     "ILS": 3.69763499,
#     "IMP": 0.87614074,
#     "INR": 107.51934756,
#     "IQD": 1549.00429185,
#     "IRR": 1549079.88412009,
#     "ISK": 143.45858115,
#     "JEP": 0.87614074,
#     "JMD": 184.38938175,
#     "JOD": 0.83550583,
#     "JPY": 183.88112091,
#     "KES": 152.35576841,
#     "KGS": 103.30330763,
#     "KHR": 4748.92105263,
#     "KID": 1.6651015,
#     "KMF": 491.96775,
#     "KRW": 1702.28401933,
#     "KWD": 0.36104653,
#     "KYD": 0.98202339,
#     "KZT": 588.71379125,
#     "LAK": 25720.71500982,
#     "LBP": 105469.35393634,
#     "LKR": 364.37831482,
#     "LRD": 216.75274998,
#     "LSL": 18.88232198,
#     "LYD": 7.46129993,
#     "MAD": 10.80914099,
#     "MDL": 20.1260567,
#     "MGA": 4944.06807089,
#     "MKD": 61.6948,
#     "MMK": 2487.96429077,
#     "MNT": 4184.52465278,
#     "MOP": 9.49216753,
#     "MRU": 47.3148925,
#     "MUR": 54.68650178,
#     "MVR": 18.26158613,
#     "MWK": 2052.81852401,
#     "MXN": 20.38537078,
#     "MYR": 4.59517659,
#     "MZN": 75.55682259,
#     "NAD": 18.88232198,
#     "NGN": 1599.14562768,
#     "NIO": 43.45924211,
#     "NOK": 11.21742644,
#     "NPR": 172.03079842,
#     "NZD": 1.97341347,
#     "OMR": 0.45310224,
#     "PAB": 1.17842854,
#     "PEN": 3.9629113,
#     "PGK": 5.14540601,
#     "PHP": 68.1540011,
#     "PKR": 330.38630829,
#     "PLN": 4.22468543,
#     "PYG": 7667.64768056,
#     "QAR": 4.28947987,
#     "RON": 5.09490219,
#     "RSD": 117.45122636,
#     "RUB": 91.32515416,
#     "RWF": 1720.06705314,
#     "SAR": 4.41910701,
#     "SBD": 9.29847539,
#     "SCR": 16.55805215,
#     "SDG": 528.43045388,
#     "SEK": 10.66851598,
#     "SGD": 1.4939172,
#     "SHP": 0.87614074,
#     "SLE": 28.84812942,
#     "SLL": 28848.23854747,
#     "SOS": 674.61308411,
#     "SRD": 44.64044527,
#     "SSP": 5414.00038168,
#     "STN": 24.5,
#     "SYP": 135.87603033,
#     "SZL": 18.88232198,
#     "THB": 36.68469217,
#     "TJS": 11.08250613,
#     "TMT": 4.13312443,
#     "TND": 3.38044622,
#     "TOP": 2.74744398,
#     "TRY": 51.78950638,
#     "TTD": 8.60348582,
#     "TVD": 1.6651015,
#     "TWD": 37.06021319,
#     "TZS": 3016.86267936,
#     "UAH": 50.93754607,
#     "UGX": 4227.42149069,
#     "USD": 1.17858471,
#     "UYU": 45.40690638,
#     "UZS": 14414.69411932,
#     "VES": 495.60601336,
#     "VND": 30457.73749569,
#     "VUV": 138.59240474,
#     "WST": 3.13575042,
#     "XAF": 655.957,
#     "XCD": 3.18175705,
#     "XCG": 2.10938708,
#     "XDR": 0.85842039,
#     "XOF": 655.957,
#     "XPF": 119.332,
#     "YER": 281.49797662,
#     "ZAR": 18.88551489,
#     "ZMW": 22.22841983,
#     "ZWG": 30.44219996,
#     "ZWL": 30.4422
#   }
# }

# %%
currencies = ['NOK', 'EUR', 'SEK', 'PLN', 'RON', 'DKK', 'CZK']

# %% [markdown]
# ### Explaination :
#
# - 1 Eur = 10.83 Sek
# - 1 Eur = 11.54 Nok
#
# - 1 Nok = 1/11.54
# - 1 Sek = 1/10.83
#
# - Base to Target = base_rate_currency / target_rate_currency
#
# - Nok/Sek = 1 Nok = 1/11.54 / 1/10.83 OR 1/11.54 * 10.83 = xx Sek

# %%
from itertools import combinations, permutations
'''
Combinations if we want to have unique pairs
Permutations to have all pairs and facilitate queries for analysis
'''  

currencies = ['NOK', 'EUR', 'SEK', 'PLN', 'RON', 'DKK', 'CZK']

rates_vs_eur = {currency: data['conversion_rates'][currency] for currency in currencies}

cross_pairs = {}
for base, target in permutations(currencies, 2):
    pair = f"{base}/{target}"
    cross_pairs[pair] = rates_vs_eur[target] / rates_vs_eur[base]
    print(pair)
    print(f"{rates_vs_eur[target]} / {rates_vs_eur[base]}")
# Out:
# NOK/EUR
# 1 / 11.21742644
# NOK/SEK
# 10.66851598 / 11.21742644
# NOK/PLN
# 4.22468543 / 11.21742644
# NOK/RON
# 5.09490219 / 11.21742644
# NOK/DKK
# 7.46083908 / 11.21742644
# NOK/CZK
# 24.24255538 / 11.21742644
# EUR/NOK
# 11.21742644 / 1
# EUR/SEK
# 10.66851598 / 1
# EUR/PLN
# 4.22468543 / 1
# EUR/RON
# 5.09490219 / 1
# EUR/DKK
# 7.46083908 / 1
# EUR/CZK
# 24.24255538 / 1
# SEK/NOK
# 11.21742644 / 10.66851598
# SEK/EUR
# 1 / 10.66851598
# SEK/PLN
# 4.22468543 / 10.66851598
# SEK/RON
# 5.09490219 / 10.66851598
# SEK/DKK
# 7.46083908 / 10.66851598
# SEK/CZK
# 24.24255538 / 10.66851598
# PLN/NOK
# 11.21742644 / 4.22468543
# PLN/EUR
# 1 / 4.22468543
# PLN/SEK
# 10.66851598 / 4.22468543
# PLN/RON
# 5.09490219 / 4.22468543
# PLN/DKK
# 7.46083908 / 4.22468543
# PLN/CZK
# 24.24255538 / 4.22468543
# RON/NOK
# 11.21742644 / 5.09490219
# RON/EUR
# 1 / 5.09490219
# RON/SEK
# 10.66851598 / 5.09490219
# RON/PLN
# 4.22468543 / 5.09490219
# RON/DKK
# 7.46083908 / 5.09490219
# RON/CZK
# 24.24255538 / 5.09490219
# DKK/NOK
# 11.21742644 / 7.46083908
# DKK/EUR
# 1 / 7.46083908
# DKK/SEK
# 10.66851598 / 7.46083908
# DKK/PLN
# 4.22468543 / 7.46083908
# DKK/RON
# 5.09490219 / 7.46083908
# DKK/CZK
# 24.24255538 / 7.46083908
# CZK/NOK
# 11.21742644 / 24.24255538
# CZK/EUR
# 1 / 24.24255538
# CZK/SEK
# 10.66851598 / 24.24255538
# CZK/PLN
# 4.22468543 / 24.24255538
# CZK/RON
# 5.09490219 / 24.24255538
# CZK/DKK
# 7.46083908 / 24.24255538

# %%
for pair, rate in cross_pairs.items():
    print(f"{pair}: {rate:.6f}")
# Out:
# NOK/EUR: 0.089147
# NOK/SEK: 0.951066
# NOK/PLN: 0.376618
# NOK/RON: 0.454195
# NOK/DKK: 0.665111
# NOK/CZK: 2.161151
# EUR/NOK: 11.217426
# EUR/SEK: 10.668516
# EUR/PLN: 4.224685
# EUR/RON: 5.094902
# EUR/DKK: 7.460839
# EUR/CZK: 24.242555
# SEK/NOK: 1.051451
# SEK/EUR: 0.093734
# SEK/PLN: 0.395996
# SEK/RON: 0.477564
# SEK/DKK: 0.699332
# SEK/CZK: 2.272346
# PLN/NOK: 2.655210
# PLN/EUR: 0.236704
# PLN/SEK: 2.525281
# PLN/RON: 1.205984
# PLN/DKK: 1.766011
# PLN/CZK: 5.738310
# RON/NOK: 2.201696
# RON/EUR: 0.196275
# RON/SEK: 2.093959
# RON/PLN: 0.829199
# RON/DKK: 1.464373
# RON/CZK: 4.758198
# DKK/NOK: 1.503507
# DKK/EUR: 0.134033
# DKK/SEK: 1.429935
# DKK/PLN: 0.566248
# DKK/RON: 0.682886
# DKK/CZK: 3.249307
# CZK/NOK: 0.462716
# CZK/EUR: 0.041250
# CZK/SEK: 0.440074
# CZK/PLN: 0.174267
# CZK/RON: 0.210164
# CZK/DKK: 0.307758

# %%
len(cross_pairs)
# Out:
# 42

# %% [markdown]
# ### Pairs should be 42 :
#
# 7 currencies with 6 variations : 7 * (7-1)/2 = 21 * 2(for duplicates EUR/NOK - NOK/EUR) = 42

# %% [markdown]
# ### Fetch historical data

# %%
import os
import requests
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv

# %%
load_dotenv()

api_key = os.getenv("api_key")
# api_key

# %%
base_currency = "EUR"
target_currencies = ["NOK", "EUR", "SEK", "PLN", "RON", "DKK", "CZK"]

# %%
start_date = datetime(2026, 2, 26)
end_date = datetime.today()

# %%
records = []
current_date = start_date

# %%
current_date
# Out:
# datetime.datetime(2026, 2, 26, 0, 0)

# %%
start_date
# Out:
# datetime.datetime(2026, 2, 26, 0, 0)

# %%
while current_date < end_date:
    year    = current_date.year
    month   = current_date.month
    day     = current_date.day

    url = f"https://v6.exchangerate-api.com/v6/{api_key}/history/EUR/{year}/{month}/{day}"
    response = requests.get(url)
    data = response.json()

    try:
        rates = data["conversion_rates"]
        record = {"date" : current_date.strftime("%Y-%m-%d")}
        
        for currency in target_currencies:
            record[currency] = rates.get(currency) 
        
        records.append(record)

        current_date += timedelta(days=1)
    except Exception as e:
        print("ERROR : ", e)

# %%
records
# Out:
# [{'date': '2026-02-26',
#   'NOK': 11.28407463,
#   'EUR': 1,
#   'SEK': 10.65796541,
#   'PLN': 4.2181691,
#   'RON': 5.09443304,
#   'DKK': 7.46330265,
#   'CZK': 24.22916733},
#  {'date': '2026-02-27',
#   'NOK': 11.27947743,
#   'EUR': 1,
#   'SEK': 10.67802938,
#   'PLN': 4.22261816,
#   'RON': 5.09501245,
#   'DKK': 7.46346323,
#   'CZK': 24.2493814},
#  {'date': '2026-02-28',
#   'NOK': 11.23775346,
#   'EUR': 1,
#   'SEK': 10.66789828,
#   'PLN': 4.22473171,
#   'RON': 5.09591778,
#   'DKK': 7.46343647,
#   'CZK': 24.24158178},
#  {'date': '2026-03-01',
#   'NOK': 11.21742644,
#   'EUR': 1,
#   'SEK': 10.66851598,
#   'PLN': 4.22468543,
#   'RON': 5.09490219,
#   'DKK': 7.46083908,
#   'CZK': 24.24255538}]

# %%
df = pd.DataFrame(records)
df
# Out:
#          date        NOK  EUR        SEK       PLN       RON       DKK  \
# 0  2026-02-26  11.284075    1  10.657965  4.218169  5.094433  7.463303
# 1  2026-02-27  11.279477    1  10.678029  4.222618  5.095012  7.463463
# 2  2026-02-28  11.237753    1  10.667898  4.224732  5.095918  7.463436
# 3  2026-03-01  11.217426    1  10.668516  4.224685  5.094902  7.460839
#
#          CZK
# 0  24.229167
# 1  24.249381
# 2  24.241582
# 3  24.242555

# %% [markdown]
# ### Cross pairs

# %%
from itertools import permutations

# %%
currencies = ["NOK", "EUR", "SEK", "PLN", "RON", "DKK", "CZK"]

# %%
cross_pairs = []

# %%
for _, row in df.iterrows():
    for base, target in permutations(currencies, 2):
        rate = row[target] / row[base]
        cross_pairs.append({
            "date": row["date"],
            "base_currency": base,
            "target_currency": target,
            "rate": round(rate, 6)
        })

# %%
cross_pairs
# Out:
# [{'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'EUR',
#   'rate': 0.08862},
#  {'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'SEK',
#   'rate': 0.944514},
#  {'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'PLN',
#   'rate': 0.373816},
#  {'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'RON',
#   'rate': 0.451471},
#  {'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'DKK',
#   'rate': 0.661401},
#  {'date': '2026-02-26',
#   'base_currency': 'NOK',
#   'target_currency': 'CZK',
#   'rate': 2.1472},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'NOK',
#   'rate': 11.284075},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'SEK',
#   'rate': 10.657965},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'PLN',
#   'rate': 4.218169},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'RON',
#   'rate': 5.094433},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'DKK',
#   'rate': 7.463303},
#  {'date': '2026-02-26',
#   'base_currency': 'EUR',
#   'target_currency': 'CZK',
#   'rate': 24.229167},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'NOK',
#   'rate': 1.058746},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'EUR',
#   'rate': 0.093827},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'PLN',
#   'rate': 0.395776},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'RON',
#   'rate': 0.477993},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'DKK',
#   'rate': 0.700256},
#  {'date': '2026-02-26',
#   'base_currency': 'SEK',
#   'target_currency': 'CZK',
#   'rate': 2.273339},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'NOK',
#   'rate': 2.675112},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'EUR',
#   'rate': 0.23707},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'SEK',
#   'rate': 2.52668},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'RON',
#   'rate': 1.207736},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'DKK',
#   'rate': 1.769323},
#  {'date': '2026-02-26',
#   'base_currency': 'PLN',
#   'target_currency': 'CZK',
#   'rate': 5.744001},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'NOK',
#   'rate': 2.214981},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'EUR',
#   'rate': 0.196293},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'SEK',
#   'rate': 2.092081},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'PLN',
#   'rate': 0.827996},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'DKK',
#   'rate': 1.464992},
#  {'date': '2026-02-26',
#   'base_currency': 'RON',
#   'target_currency': 'CZK',
#   'rate': 4.756009},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'NOK',
#   'rate': 1.511941},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'EUR',
#   'rate': 0.133989},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'SEK',
#   'rate': 1.428049},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'PLN',
#   'rate': 0.565188},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'RON',
#   'rate': 0.682598},
#  {'date': '2026-02-26',
#   'base_currency': 'DKK',
#   'target_currency': 'CZK',
#   'rate': 3.24644},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'NOK',
#   'rate': 0.465723},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'EUR',
#   'rate': 0.041273},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'SEK',
#   'rate': 0.439882},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'PLN',
#   'rate': 0.174095},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'RON',
#   'rate': 0.21026},
#  {'date': '2026-02-26',
#   'base_currency': 'CZK',
#   'target_currency': 'DKK',
#   'rate': 0.30803},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'EUR',
#   'rate': 0.088657},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'SEK',
#   'rate': 0.946678},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'PLN',
#   'rate': 0.374363},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'RON',
#   'rate': 0.451706},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'DKK',
#   'rate': 0.661685},
#  {'date': '2026-02-27',
#   'base_currency': 'NOK',
#   'target_currency': 'CZK',
#   'rate': 2.149867},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'NOK',
#   'rate': 11.279477},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'SEK',
#   'rate': 10.678029},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'PLN',
#   'rate': 4.222618},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'RON',
#   'rate': 5.095012},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'DKK',
#   'rate': 7.463463},
#  {'date': '2026-02-27',
#   'base_currency': 'EUR',
#   'target_currency': 'CZK',
#   'rate': 24.249381},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'NOK',
#   'rate': 1.056326},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'EUR',
#   'rate': 0.09365},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'PLN',
#   'rate': 0.395449},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'RON',
#   'rate': 0.477149},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'DKK',
#   'rate': 0.698955},
#  {'date': '2026-02-27',
#   'base_currency': 'SEK',
#   'target_currency': 'CZK',
#   'rate': 2.27096},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'NOK',
#   'rate': 2.671205},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'EUR',
#   'rate': 0.23682},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'SEK',
#   'rate': 2.52877},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'RON',
#   'rate': 1.2066},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'DKK',
#   'rate': 1.767497},
#  {'date': '2026-02-27',
#   'base_currency': 'PLN',
#   'target_currency': 'CZK',
#   'rate': 5.742736},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'NOK',
#   'rate': 2.213827},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'EUR',
#   'rate': 0.19627},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'SEK',
#   'rate': 2.095781},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'PLN',
#   'rate': 0.828775},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'DKK',
#   'rate': 1.464857},
#  {'date': '2026-02-27',
#   'base_currency': 'RON',
#   'target_currency': 'CZK',
#   'rate': 4.759435},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'NOK',
#   'rate': 1.511293},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'EUR',
#   'rate': 0.133986},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'SEK',
#   'rate': 1.430707},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'PLN',
#   'rate': 0.565772},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'RON',
#   'rate': 0.682661},
#  {'date': '2026-02-27',
#   'base_currency': 'DKK',
#   'target_currency': 'CZK',
#   'rate': 3.249079},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'NOK',
#   'rate': 0.465145},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'EUR',
#   'rate': 0.041238},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'SEK',
#   'rate': 0.440342},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'PLN',
#   'rate': 0.174133},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'RON',
#   'rate': 0.210109},
#  {'date': '2026-02-27',
#   'base_currency': 'CZK',
#   'target_currency': 'DKK',
#   'rate': 0.30778},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'EUR',
#   'rate': 0.088986},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'SEK',
#   'rate': 0.949291},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'PLN',
#   'rate': 0.375941},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'RON',
#   'rate': 0.453464},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'DKK',
#   'rate': 0.66414},
#  {'date': '2026-02-28',
#   'base_currency': 'NOK',
#   'target_currency': 'CZK',
#   'rate': 2.157156},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'NOK',
#   'rate': 11.237753},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'SEK',
#   'rate': 10.667898},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'PLN',
#   'rate': 4.224732},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'RON',
#   'rate': 5.095918},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'DKK',
#   'rate': 7.463436},
#  {'date': '2026-02-28',
#   'base_currency': 'EUR',
#   'target_currency': 'CZK',
#   'rate': 24.241582},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'NOK',
#   'rate': 1.053418},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'EUR',
#   'rate': 0.093739},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'PLN',
#   'rate': 0.396023},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'RON',
#   'rate': 0.477687},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'DKK',
#   'rate': 0.699616},
#  {'date': '2026-02-28',
#   'base_currency': 'SEK',
#   'target_currency': 'CZK',
#   'rate': 2.272386},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'NOK',
#   'rate': 2.659992},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'EUR',
#   'rate': 0.236701},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'SEK',
#   'rate': 2.525107},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'RON',
#   'rate': 1.206211},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'DKK',
#   'rate': 1.766606},
#  {'date': '2026-02-28',
#   'base_currency': 'PLN',
#   'target_currency': 'CZK',
#   'rate': 5.738017},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'NOK',
#   'rate': 2.205246},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'EUR',
#   'rate': 0.196236},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'SEK',
#   'rate': 2.09342},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'PLN',
#   'rate': 0.829042},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'DKK',
#   'rate': 1.464591},
#  {'date': '2026-02-28',
#   'base_currency': 'RON',
#   'target_currency': 'CZK',
#   'rate': 4.757059},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'NOK',
#   'rate': 1.505708},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'EUR',
#   'rate': 0.133987},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'SEK',
#   'rate': 1.429355},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'PLN',
#   'rate': 0.566057},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'RON',
#   'rate': 0.682784},
#  {'date': '2026-02-28',
#   'base_currency': 'DKK',
#   'target_currency': 'CZK',
#   'rate': 3.248046},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'NOK',
#   'rate': 0.463573},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'EUR',
#   'rate': 0.041251},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'SEK',
#   'rate': 0.440066},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'PLN',
#   'rate': 0.174276},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'RON',
#   'rate': 0.210214},
#  {'date': '2026-02-28',
#   'base_currency': 'CZK',
#   'target_currency': 'DKK',
#   'rate': 0.307877},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'EUR',
#   'rate': 0.089147},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'SEK',
#   'rate': 0.951066},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'PLN',
#   'rate': 0.376618},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'RON',
#   'rate': 0.454195},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'DKK',
#   'rate': 0.665111},
#  {'date': '2026-03-01',
#   'base_currency': 'NOK',
#   'target_currency': 'CZK',
#   'rate': 2.161151},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'NOK',
#   'rate': 11.217426},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'SEK',
#   'rate': 10.668516},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'PLN',
#   'rate': 4.224685},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'RON',
#   'rate': 5.094902},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'DKK',
#   'rate': 7.460839},
#  {'date': '2026-03-01',
#   'base_currency': 'EUR',
#   'target_currency': 'CZK',
#   'rate': 24.242555},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'NOK',
#   'rate': 1.051451},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'EUR',
#   'rate': 0.093734},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'PLN',
#   'rate': 0.395996},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'RON',
#   'rate': 0.477564},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'DKK',
#   'rate': 0.699332},
#  {'date': '2026-03-01',
#   'base_currency': 'SEK',
#   'target_currency': 'CZK',
#   'rate': 2.272346},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'NOK',
#   'rate': 2.65521},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'EUR',
#   'rate': 0.236704},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'SEK',
#   'rate': 2.525281},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'RON',
#   'rate': 1.205984},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'DKK',
#   'rate': 1.766011},
#  {'date': '2026-03-01',
#   'base_currency': 'PLN',
#   'target_currency': 'CZK',
#   'rate': 5.73831},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'NOK',
#   'rate': 2.201696},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'EUR',
#   'rate': 0.196275},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'SEK',
#   'rate': 2.093959},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'PLN',
#   'rate': 0.829199},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'DKK',
#   'rate': 1.464373},
#  {'date': '2026-03-01',
#   'base_currency': 'RON',
#   'target_currency': 'CZK',
#   'rate': 4.758198},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'NOK',
#   'rate': 1.503507},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'EUR',
#   'rate': 0.134033},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'SEK',
#   'rate': 1.429935},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'PLN',
#   'rate': 0.566248},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'RON',
#   'rate': 0.682886},
#  {'date': '2026-03-01',
#   'base_currency': 'DKK',
#   'target_currency': 'CZK',
#   'rate': 3.249307},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'NOK',
#   'rate': 0.462716},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'EUR',
#   'rate': 0.04125},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'SEK',
#   'rate': 0.440074},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'PLN',
#   'rate': 0.174267},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'RON',
#   'rate': 0.210164},
#  {'date': '2026-03-01',
#   'base_currency': 'CZK',
#   'target_currency': 'DKK',
#   'rate': 0.307758}]

# %%
df_pairs = pd.DataFrame(cross_pairs)
df_pairs
# Out:
#            date base_currency target_currency      rate
# 0    2026-02-26           NOK             EUR  0.088620
# 1    2026-02-26           NOK             SEK  0.944514
# 2    2026-02-26           NOK             PLN  0.373816
# 3    2026-02-26           NOK             RON  0.451471
# 4    2026-02-26           NOK             DKK  0.661401
# ..          ...           ...             ...       ...
# 163  2026-03-01           CZK             EUR  0.041250
# 164  2026-03-01           CZK             SEK  0.440074
# 165  2026-03-01           CZK             PLN  0.174267
# 166  2026-03-01           CZK             RON  0.210164
# 167  2026-03-01           CZK             DKK  0.307758
#
# [168 rows x 4 columns]

# %%
168 / 42
# Out:
# 4.0

# %%
df['date'].value_counts()
# Out:
# date
# 2026-02-26    1
# 2026-02-27    1
# 2026-02-28    1
# 2026-03-01    1
# Name: count, dtype: int64

# %%
df_pairs['date'].value_counts()
# Out:
# date
# 2026-02-26    42
# 2026-02-27    42
# 2026-02-28    42
# 2026-03-01    42
# Name: count, dtype: int64

# %% [markdown]
# ### Why long format (currencies in rows) and not wide format (currencies as columns):
# - Scalability : Alter schema is simple : No need for DDL to modify schema. Eg: adding new curr : api call or calculations, more tricky, need to calculate every column CASE WHEN...
# -  Easy joins : base curr and target curr,

# %% [markdown]
# ## Dimensional table : dim currency

# %%
currencies
# Out:
# ['NOK', 'EUR', 'SEK', 'PLN', 'RON', 'DKK', 'CZK']

# %%
dim = []

for currency in currencies:
    response = requests.get(f"https://v6.exchangerate-api.com/v6/{api_key}/enriched/EUR/{currency}")
    data = response.json()

    if data.get("result") == "success":
        dim.append({
            "currency": data["target_code"]
            , "locale" : data["target_data"]["locale"]
            , "two_letter_code" : data["target_data"]["two_letter_code"]
            , "currency_name" : data["target_data"]["currency_name"]
            , "currency_name_short" : data["target_data"]["currency_name_short"]
        })
    else:
        print(data.get("result"))

# %%
dim
# Out:
# [{'currency': 'NOK',
#   'locale': 'Norway',
#   'two_letter_code': 'NO',
#   'currency_name': 'Norwegian Krone',
#   'currency_name_short': 'Krone'},
#  {'currency': 'EUR',
#   'locale': 'European Union',
#   'two_letter_code': 'EU',
#   'currency_name': 'Euro',
#   'currency_name_short': 'Euro'},
#  {'currency': 'SEK',
#   'locale': 'Sweden',
#   'two_letter_code': 'SE',
#   'currency_name': 'Swedish Krona',
#   'currency_name_short': 'Krona'},
#  {'currency': 'PLN',
#   'locale': 'Poland',
#   'two_letter_code': 'PL',
#   'currency_name': 'Polish Złoty',
#   'currency_name_short': 'Złoty'},
#  {'currency': 'RON',
#   'locale': 'Romania',
#   'two_letter_code': 'RO',
#   'currency_name': 'Romanian Leu',
#   'currency_name_short': 'Leu'},
#  {'currency': 'DKK',
#   'locale': 'Denmark',
#   'two_letter_code': 'DK',
#   'currency_name': 'Danish Krone',
#   'currency_name_short': 'Krone'},
#  {'currency': 'CZK',
#   'locale': 'Czech Republic',
#   'two_letter_code': 'CZ',
#   'currency_name': 'Czech Koruna',
#   'currency_name_short': 'Koruna'}]

# %%
df_dim = pd.DataFrame(dim)
df_dim
# Out:
#   currency          locale two_letter_code    currency_name  \
# 0      NOK          Norway              NO  Norwegian Krone
# 1      EUR  European Union              EU             Euro
# 2      SEK          Sweden              SE    Swedish Krona
# 3      PLN          Poland              PL     Polish Złoty
# 4      RON         Romania              RO     Romanian Leu
# 5      DKK         Denmark              DK     Danish Krone
# 6      CZK  Czech Republic              CZ     Czech Koruna
#
#   currency_name_short
# 0               Krone
# 1                Euro
# 2               Krona
# 3               Złoty
# 4                 Leu
# 5               Krone
# 6              Koruna

# %% [markdown]
# ### Schema DDL Data Definiton Language :
# - Dim Date   : date, year, fiscal_year, month, quarter, fiscal_quarter
# - Dim Curr   : locale, two_letter_code, currency_name, currency_name_short
# - Fact Rates : base_curr, target_curr

# %%
import sqlite3

# %%
db_path = "fx_warehouse.sqlite"

# %%
conn = sqlite3.connect(db_path)
conn

# %%
cursor = conn.cursor()

# %% [markdown]
# ### Create Dimension tables: Currency and Date

# %%
df_dim
# Out:
#   currency          locale two_letter_code    currency_name  \
# 0      NOK          Norway              NO  Norwegian Krone
# 1      EUR  European Union              EU             Euro
# 2      SEK          Sweden              SE    Swedish Krona
# 3      PLN          Poland              PL     Polish Złoty
# 4      RON         Romania              RO     Romanian Leu
# 5      DKK         Denmark              DK     Danish Krone
# 6      CZK  Czech Republic              CZ     Czech Koruna
#
#   currency_name_short
# 0               Krone
# 1                Euro
# 2               Krona
# 3               Złoty
# 4                 Leu
# 5               Krone
# 6              Koruna

# %%
df_pairs
# Out:
#            date base_currency target_currency      rate
# 0    2026-02-26           NOK             EUR  0.088620
# 1    2026-02-26           NOK             SEK  0.944514
# 2    2026-02-26           NOK             PLN  0.373816
# 3    2026-02-26           NOK             RON  0.451471
# 4    2026-02-26           NOK             DKK  0.661401
# ..          ...           ...             ...       ...
# 163  2026-03-01           CZK             EUR  0.041250
# 164  2026-03-01           CZK             SEK  0.440074
# 165  2026-03-01           CZK             PLN  0.174267
# 166  2026-03-01           CZK             RON  0.210164
# 167  2026-03-01           CZK             DKK  0.307758
#
# [168 rows x 4 columns]

# %% [markdown]
# #### Date dim

# %%
from datetime import datetime, timedelta

# %%
date_records = []
current = datetime(2026, 1, 1)
end = datetime.today()

# %%
# cursor.execute("""
#     DROP TABLE dim_date
# """)

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS dim_date(
        date TEXT PRIMARY KEY
        , year INTEGER NOT NULL
        , fiscal_year INTEGER NOT NULL
        , month INTEGER NOT NULL
        , day INTEGER NOT NULL
        , quarter INTEGER NOT NULL
    );
""")

# %%
while current < end:
    fiscal_year = current.year + 1 if current.month >= 10 else current.year 
    date_records.append((
        current.strftime("%Y-%m-%d")
        , current.year
        , fiscal_year
        , current.month
        , current.day
        , (current.month - 1) // 3 + 1
    ))

    current += timedelta(days=1)

# %%
date_records[:3]
# Out:
# [('2025-01-01', 2025, 2025, 1, 1, 1),
#  ('2025-01-02', 2025, 2025, 1, 2, 1),
#  ('2025-01-03', 2025, 2025, 1, 3, 1)]

# %%
cursor.executemany("""
    INSERT INTO dim_date(date, year, fiscal_year, month, day, quarter)
    VALUES(?, ?, ?, ?, ?, ?)
""", date_records)

# %%
conn.commit()

# %% [markdown]
# #### Dim currencies

# %%
df_dim
# Out:
#   currency          locale two_letter_code    currency_name  \
# 0      NOK          Norway              NO  Norwegian Krone
# 1      EUR  European Union              EU             Euro
# 2      SEK          Sweden              SE    Swedish Krona
# 3      PLN          Poland              PL     Polish Złoty
# 4      RON         Romania              RO     Romanian Leu
# 5      DKK         Denmark              DK     Danish Krone
# 6      CZK  Czech Republic              CZ     Czech Koruna
#
#   currency_name_short
# 0               Krone
# 1                Euro
# 2               Krona
# 3               Złoty
# 4                 Leu
# 5               Krone
# 6              Koruna

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS dim_currencies(
            currency TEXT PRIMARY KEY
            , locale TEXT NOT NULL
            , two_letter_code TEXT NOT NULL
            , currency_name TEXT NOT NULL
            , currency_name_short TEXT NOT NULL
        );
""")

# %%
df_dim
# Out:
#   currency          locale two_letter_code    currency_name  \
# 0      NOK          Norway              NO  Norwegian Krone
# 1      EUR  European Union              EU             Euro
# 2      SEK          Sweden              SE    Swedish Krona
# 3      PLN          Poland              PL     Polish Złoty
# 4      RON         Romania              RO     Romanian Leu
# 5      DKK         Denmark              DK     Danish Krone
# 6      CZK  Czech Republic              CZ     Czech Koruna
#
#   currency_name_short
# 0               Krone
# 1                Euro
# 2               Krona
# 3               Złoty
# 4                 Leu
# 5               Krone
# 6              Koruna

# %%
df_dim.to_sql("dim_currencies", conn, if_exists="append", index=False)
# Out:
# 7

# %% [markdown]
# ### Fact Foreign Exchange Rates

# %%
df_pairs.to_sql("fact_fx_rates", conn, if_exists="replace", index=False)
# Out:
# 168

# %% [markdown]
# ### QUERIES

# %%
cursor.execute("""
    SELECT
        *
    FROM fact_fx_rates AS fx
    LEFT JOIN dim_date AS dd ON fx.date = dd.date
""").fetchall()

# %%
cursor.execute("""
    SELECT
        fx.*
        , dd.year
        , dd.month
        , dd.quarter
        , dc.*
    FROM fact_fx_rates AS fx
    LEFT JOIN dim_date AS dd ON fx.date = dd.date
    LEFT JOIN dim_currencies dc ON fx.base_currency = dc.currency
               
    WHERE fx.date = '2026-03-01'
    AND   fx.base_currency = 'NOK'
    AND   fx.target_currency = 'EUR'
""").fetchall()
# Out:
# [('2026-03-01',
#   'NOK',
#   'EUR',
#   0.089147,
#   2026,
#   3,
#   1,
#   'NOK',
#   'Norway',
#   'NO',
#   'Norwegian Krone',
#   'Krone')]

# %%
pd.read_sql("""
    SELECT
        fx.*
        , dd.year
        , dd.month
        , dd.quarter
        , dc.*
    FROM fact_fx_rates AS fx
    LEFT JOIN dim_date AS dd ON fx.date = dd.date
    LEFT JOIN dim_currencies dc ON fx.base_currency = dc.currency
               
    WHERE fx.date = '2026-03-01'
    AND   fx.base_currency = 'NOK'
    AND   fx.target_currency = 'EUR'
""", conn)
# Out:
#          date base_currency target_currency      rate  year  month  quarter  \
# 0  2026-03-01           NOK             EUR  0.089147  2026      3        1
#
#   currency  locale two_letter_code    currency_name currency_name_short
# 0      NOK  Norway              NO  Norwegian Krone               Krone

# %% [markdown]
# ### Year To Date (YTD) :
# - From 1st jan to current date
# - Percentage Change = (current_date - 1st jan) / 1st jan * 100
# - Rates accumulation

# %%
df_pairs
# Out:
#            date base_currency target_currency      rate
# 0    2026-02-26           NOK             EUR  0.088620
# 1    2026-02-26           NOK             SEK  0.944514
# 2    2026-02-26           NOK             PLN  0.373816
# 3    2026-02-26           NOK             RON  0.451471
# 4    2026-02-26           NOK             DKK  0.661401
# ..          ...           ...             ...       ...
# 163  2026-03-01           CZK             EUR  0.041250
# 164  2026-03-01           CZK             SEK  0.440074
# 165  2026-03-01           CZK             PLN  0.174267
# 166  2026-03-01           CZK             RON  0.210164
# 167  2026-03-01           CZK             DKK  0.307758
#
# [168 rows x 4 columns]

# %%
pd.read_sql("""
    WITH SUB AS(
        SELECT
            *
            , ROW_NUMBER() OVER(PARTITION BY base_currency, target_currency ORDER BY rate DESC) Max_Rate_RN
            , AVG(rate) OVER(PARTITION BY base_currency, target_currency) AS avg_rate
            , MAX(CASE WHEN date = '2026-02-26' THEN rate END) OVER(PARTITION BY base_currency, target_currency) AS jan_1st_rate
            , ROW_NUMBER() OVER(PARTITION BY base_currency, target_currency ORDER BY DATE DESC) AS last_date_RN
        FROM fact_fx_rates
        -- WHERE date >= '2026-01-01'
    )
            
    SELECT
        *
    FROM SUB
    --WHERE MAX_RATE_RN = 1
    WHERE base_currency = 'EUR'
    AND target_currency = 'NOK'
""", conn)
# Out:
#          date base_currency target_currency       rate  Max_Rate_RN  \
# 0  2026-02-26           EUR             NOK  11.284075            1
# 1  2026-02-27           EUR             NOK  11.279477            2
# 2  2026-02-28           EUR             NOK  11.237753            3
# 3  2026-03-01           EUR             NOK  11.217426            4
#
#     avg_rate  jan_1st_rate  last_date_RN
# 0  11.254683     11.284075             4
# 1  11.254683     11.284075             3
# 2  11.254683     11.284075             2
# 3  11.254683     11.284075             1

# %%
import sqlite3
import pandas as pd

# %%
db_path = "../data/fx_warehouse.sqlite"
conn = sqlite3.connect(db_path)

# %%
ytd_query = """
    WITH first_rate AS(
        SELECT
            base_currency	
            , target_currency
            , date AS first_date
            , rate AS first_rate	
        FROM fact_fx_rates 
        WHERE date = (SELECT MIN(date) FROM fact_fx_rates WHERE strftime('%Y', date) = strftime('%Y', 'now')) 
    ), 

    last_rate AS(
        SELECT
            base_currency	
            , target_currency
            , date AS last_date
            , rate AS last_rate
        FROM fact_fx_rates 
        WHERE date = (SELECT MAX(date) FROM fact_fx_rates WHERE strftime('%Y', date) = strftime('%Y', 'now'))	
    ),
    
    all_rates AS(
        SELECT
            base_currency	
            , target_currency
            , MIN(rate) AS min_rate
            , MAX(rate) AS max_rate
            , AVG(rate) AS avg_rate
        FROM fact_fx_rates
        WHERE strftime('%Y', date) = strftime('%Y', 'now')
        GROUP BY base_currency	
            , target_currency
    ) 

    SELECT
        FR.*    
        , LR.last_date
        , LR.last_rate
        , AR.min_rate
        , AR.max_rate
        , AR.avg_rate
        , ROUND((LR.last_rate - FR.first_rate) / FR.first_rate * 100, 2) AS YTD_change_pct 
    FROM first_rate AS FR
    LEFT JOIN last_rate AS LR 
        ON  FR.base_currency = LR.base_currency
        AND FR.target_currency = LR.target_currency

    LEFT JOIN all_rates AS AR
        ON  FR.base_currency = AR.base_currency
        AND FR.target_currency = AR.target_currency
"""

# %%
pd.read_sql(ytd_query, conn)
# Out:
#    base_currency target_currency  first_date  first_rate   last_date  \
# 0            CZK             DKK  2026-01-01    0.308274  2026-03-02
# 1            CZK             EUR  2026-01-01    0.041317  2026-03-02
# 2            CZK             NOK  2026-01-01    0.489100  2026-03-02
# 3            CZK             PLN  2026-01-01    0.174417  2026-03-02
# 4            CZK             RON  2026-01-01    0.210604  2026-03-02
# 5            CZK             SEK  2026-01-01    0.447079  2026-03-02
# 6            DKK             CZK  2026-01-01    3.243865  2026-03-02
# 7            DKK             EUR  2026-01-01    0.134028  2026-03-02
# 8            DKK             NOK  2026-01-01    1.586576  2026-03-02
# 9            DKK             PLN  2026-01-01    0.565786  2026-03-02
# 10           DKK             RON  2026-01-01    0.683171  2026-03-02
# 11           DKK             SEK  2026-01-01    1.450264  2026-03-02
# 12           EUR             CZK  2026-01-01   24.202961  2026-03-02
# 13           EUR             DKK  2026-01-01    7.461150  2026-03-02
# 14           EUR             NOK  2026-01-01   11.837680  2026-03-02
# 15           EUR             PLN  2026-01-01    4.221417  2026-03-02
# 16           EUR             RON  2026-01-01    5.097240  2026-03-02
# 17           EUR             SEK  2026-01-01   10.820641  2026-03-02
# 18           NOK             CZK  2026-01-01    2.044570  2026-03-02
# 19           NOK             DKK  2026-01-01    0.630288  2026-03-02
# 20           NOK             EUR  2026-01-01    0.084476  2026-03-02
# 21           NOK             PLN  2026-01-01    0.356608  2026-03-02
# 22           NOK             RON  2026-01-01    0.430595  2026-03-02
# 23           NOK             SEK  2026-01-01    0.914085  2026-03-02
# 24           PLN             CZK  2026-01-01    5.733374  2026-03-02
# 25           PLN             DKK  2026-01-01    1.767452  2026-03-02
# 26           PLN             EUR  2026-01-01    0.236887  2026-03-02
# 27           PLN             NOK  2026-01-01    2.804196  2026-03-02
# 28           PLN             RON  2026-01-01    1.207471  2026-03-02
# 29           PLN             SEK  2026-01-01    2.563272  2026-03-02
# 30           RON             CZK  2026-01-01    4.748248  2026-03-02
# 31           RON             DKK  2026-01-01    1.463763  2026-03-02
# 32           RON             EUR  2026-01-01    0.196185  2026-03-02
# 33           RON             NOK  2026-01-01    2.322370  2026-03-02
# 34           RON             PLN  2026-01-01    0.828177  2026-03-02
# 35           RON             SEK  2026-01-01    2.122843  2026-03-02
# 36           SEK             CZK  2026-01-01    2.236740  2026-03-02
# 37           SEK             DKK  2026-01-01    0.689529  2026-03-02
# 38           SEK             EUR  2026-01-01    0.092416  2026-03-02
# 39           SEK             NOK  2026-01-01    1.093991  2026-03-02
# 40           SEK             PLN  2026-01-01    0.390126  2026-03-02
# 41           SEK             RON  2026-01-01    0.471066  2026-03-02
#
#     last_rate   min_rate   max_rate   avg_rate  YTD_change_pct
# 0    0.307797   0.306270   0.308828   0.307604           -0.15
# 1    0.041241   0.041043   0.041394   0.041221           -0.18
# 2    0.461887   0.461887   0.489549   0.474358           -5.56
# 3    0.174742   0.172880   0.174742   0.173759            0.19
# 4    0.210221   0.209097   0.210785   0.209954           -0.18
# 5    0.441431   0.433283   0.447329   0.439528           -1.26
# 6    3.248891   3.238047   3.265094   3.250943            0.15
# 7    0.133989   0.133982   0.134037   0.134005           -0.03
# 8    1.500621   1.500621   1.587103   1.542100           -5.42
# 9    0.567716   0.562935   0.567716   0.564880            0.34
# 10   0.682986   0.681540   0.683273   0.682546           -0.03
# 11   1.434162   1.412182   1.450264   1.428865           -1.11
# 12  24.247438  24.158210  24.364889  24.259824            0.18
# 13   7.463298   7.460648   7.463677   7.462396            0.03
# 14  11.199581  11.199581  11.840926  11.507762           -5.39
# 15   4.237037   4.200810   4.237037   4.215358            0.37
# 16   5.097325   5.086666   5.097774   5.093425            0.00
# 17  10.703580  10.538556  10.820641  10.662755           -1.08
# 18   2.165031   2.042695   2.165031   2.108825            5.89
# 19   0.666391   0.630079   0.666391   0.648679            5.73
# 20   0.089289   0.084453   0.089289   0.086926            5.70
# 21   0.378321   0.356191   0.378321   0.366429            6.09
# 22   0.455135   0.430395   0.455135   0.442756            5.70
# 23   0.955713   0.911092   0.955713   0.926802            4.55
# 24   5.722734   5.722734   5.784358   5.755118           -0.19
# 25   1.761443   1.761443   1.776405   1.770292           -0.34
# 26   0.236014   0.236014   0.238049   0.237228           -0.37
# 27   2.643258   2.643258   2.807484   2.729991           -5.74
# 28   1.203040   1.203040   1.213139   1.208304           -0.37
# 29   2.526195   2.496043   2.566738   2.529501           -1.45
# 30   4.756894   4.744162   4.782474   4.762970            0.18
# 31   1.464160   1.463545   1.467266   1.465104            0.03
# 32   0.196181   0.196164   0.196592   0.196332           -0.00
# 33   2.197148   2.197148   2.323450   2.259353           -5.39
# 34   0.831227   0.824308   0.831227   0.827608            0.37
# 35   2.099842   2.068381   2.122843   2.093440           -1.08
# 36   2.265358   2.235490   2.307963   2.275321            1.28
# 37   0.697271   0.689529   0.708124   0.699891            1.12
# 38   0.093427   0.092416   0.094890   0.093789            1.09
# 39   1.046340   1.046340   1.097584   1.079217           -4.36
# 40   0.395852   0.389600   0.400634   0.395353            1.47
# 41   0.476226   0.471066   0.483470   0.477708            1.10

# %%
df = pd.read_sql(ytd_query, conn)
